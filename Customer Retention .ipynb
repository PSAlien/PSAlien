# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Priyanka'

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_excel("E:\ds/database_excel.xlsx")

# %%
df
# Out:
#     1Gender of respondent 2 Which city do you shop online from?  \
# 0                    Male                                 Delhi
# 1                  Female                                 Delhi
# 2                  Female                         Greater Noida
# 3                    Male                               Karnal
# 4                  Female                            Bangalore
# ..                    ...                                   ...
# 264                Female                                 Solan
# 265                Female                             Ghaziabad
# 266                Female                            Bangalore
# 267                Female                                 Solan
# 268                Female                             Ghaziabad
#
#      4 Since How Long You are Shopping Online ?  \
# 0                                             5
# 1                                             5
# 2                                             4
# ...

# %%
df.shape
# Out:
# (269, 5)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                     object
# 2 Which city do you shop online from?                                     object
# 4 Since How Long You are Shopping Online ?                                 int64
# 5 How many times you have made an online purchase in the past 1 year?      int64
# 6 Which of the Indian online retailer would you recommend to a friend?    object
# dtype: object

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 Which city do you shop online from?',
#        '4 Since How Long You are Shopping Online ?',
#        '5 How many times you have made an online purchase in the past 1 year?',
#        '6 Which of the Indian online retailer would you recommend to a friend?'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 5 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   1Gender of respondent                                                   269 non-null    object
#  1   2 Which city do you shop online from?                                   269 non-null    object
#  2   4 Since How Long You are Shopping Online ?                              269 non-null    int64
#  3   5 How many times you have made an online purchase in the past 1 year?   269 non-null    int64
#  4   6 Which of the Indian online retailer would you recommend to a friend?  269 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 10.6+ KB

# %% [markdown]
# # SUMMARY STATISTICS

# %%
df.describe()
# Out:
#        4 Since How Long You are Shopping Online ?  \
# count                                  269.000000
# mean                                     3.524164
# std                                      1.436586
# min                                      1.000000
# 25%                                      3.000000
# 50%                                      4.000000
# 75%                                      5.000000
# max                                      5.000000
#
#        5 How many times you have made an online purchase in the past 1 year?
# count                                         269.000000
# mean                                            2.672862
# std                                             1.651788
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             4.000000
# ...

# %% [markdown]
# Key Observation:
#
# 1)The mean is more than median (50th percentile) in all the columns
# 2)There is a large difference in 75% percentile and max in 4 & 5
# 3)The 1 and 2 observation suggest that there are extreme outliers present in these two columns

# %% [markdown]
# # DATA VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data set as no missing values

# %% [markdown]
# # TO check correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                                                     4 Since How Long You are Shopping Online ?  \
# 4 Since How Long You are Shopping Online ?                                            1.000000
# 5 How many times you have made an online purcha...                                    0.291104
#
#                                                     5 How many times you have made an online purchase in the past 1 year?
# 4 Since How Long You are Shopping Online ?                                                   0.291104
# 5 How many times you have made an online purcha...                                           1.000000

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation Dark shades are highly correlated

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Light shades are highly correlated
#
# Column 5 is highly correlated with column 4
#
# Column 5 is highly negatively correlated with denisty with -0.5 (see in dark maroon shade) density is highly positively correlated with column 4
#
# hence we can use column 4 from the dataset if we are doing the linear regression

# %%
df.plot(kind='kde',subplots=True,layout=(2,6),figsize=(15,6))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
sns.pairplot(df)

# %% [markdown]
# Outliers are not found in the dataset and hence after comparing the dataset with the DATA VISUALIZATION the dark shade area have less outliers
